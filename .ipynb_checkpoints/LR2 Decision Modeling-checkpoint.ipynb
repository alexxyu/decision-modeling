# %%
import math
from math import e
import pandas as pd
import matplotlib.pyplot as plt
import scipy.odr.odrpack as odrpack
from IPython.display import clear_output

# %%
import random
import numpy as np
import scipy.stats as st

class LikelihoodDecisionModel:
    
    def __init__(self):
        pass
        
    def convert_b_to_p(self, d_prime, b1, b2):
        
        if b1 > 1:
            p_hit_b1 = 1 - 2*(1 - st.norm.cdf(np.log(b1)/d_prime - d_prime/2))*(1 - st.norm.cdf(np.log(b1)/d_prime + d_prime/2))
            p_false_b1 = 1 - ((1 - st.norm.cdf(np.log(b1)/d_prime - d_prime/2))**2 + (1 - st.norm.cdf(np.log(b1)/d_prime + d_prime/2))**2)
        else:
            p_false_b1 = 2*(1 - st.norm.cdf(np.log(1/b1)/d_prime - d_prime/2))*(1 - st.norm.cdf(np.log(1/b1)/d_prime + d_prime/2))
            p_hit_b1 = ((1 - st.norm.cdf(np.log(1/b1)/d_prime - d_prime/2))**2 + (1 - st.norm.cdf(np.log(1/b1)/d_prime + d_prime/2))**2)
            
        if b2 > 1:
            p_hit_b2 = 1 - 2*(1 - st.norm.cdf(np.log(b2)/d_prime - d_prime/2))*(1 - st.norm.cdf(np.log(b2)/d_prime + d_prime/2))
            p_false_b2 = 1 - ((1 - st.norm.cdf(np.log(b2)/d_prime - d_prime/2))**2 + (1 - st.norm.cdf(np.log(b2)/d_prime + d_prime/2))**2)
        else:
            p_false_b2 = 2*(1 - st.norm.cdf(np.log(1/b2)/d_prime - d_prime/2))*(1 - st.norm.cdf(np.log(1/b2)/d_prime + d_prime/2))
            p_hit_b2 = ((1 - st.norm.cdf(np.log(1/b2)/d_prime - d_prime/2))**2 + (1 - st.norm.cdf(np.log(1/b2)/d_prime + d_prime/2))**2)
        
        p_false = (p_false_b2 + p_false_b1) / 2
        p_hit = (p_hit_b1 + p_hit_b2) / 2
        return p_false, p_hit
        
    def convert_b_to_z(self, d_prime, b1, b2):
        
        p_false, p_hit = self.convert_b_to_p(d_prime, b1, b2)
        return st.norm.ppf(p_false), st.norm.ppf(p_hit)
        
    def sample_b1_b2_values_to_z(self, b_range, d_prime, num_points):
        
        # LR2
        zf_vals = []
        zh_vals = []
        
        if d_prime == 0:
            return zf_vals, zh_vals
        
        b_range = [n for n in np.logspace(b_range['b_min'], b_range['b_max'], b_range['b_num'], base=b_range['b_base'])]
        for _ in range(num_points):
            b1 = random.choice(b_range)
            
            b2_range = [n for n in b_range if n >= b1]
            b2 = random.choice(b2_range)
            
            z_f, z_h = self.convert_b_to_z(d_prime, b1, b2)
            
            zf_vals.append(z_f)
            zh_vals.append(z_h)
            
        return zf_vals, zh_vals
    
    def sample_b1_b2_values_to_p(self, b_range, d_prime, num_points):
        
        # LR2
        pf_vals = []
        ph_vals = []
        
        if d_prime == 0:
            return zf_vals, zh_vals
        
        b_range = [n for n in np.logspace(b_range['b_min'], b_range['b_max'], b_range['b_num'], base=b_range['b_base'])]
        for _ in range(num_points):
            b1 = random.choice(b_range)
            
            b2_range = [n for n in b_range if n >= b1]
            b2 = random.choice(b2_range)
            
            p_f, p_h = self.convert_b_to_p(d_prime, b1, b2)
            
            pf_vals.append(p_f)
            ph_vals.append(p_h)
            
        return pf_vals, ph_vals
    
    def sample_b_values_to_z(self, b_range, d_prime, num_points):
        
        # LR1
        zf_vals = []
        zh_vals = []
        
        if d_prime == 0:
            return zf_vals, zh_vals
        
        b_range = [n for n in np.logspace(b_range['b_min'], b_range['b_max'], b_range['b_num'], base=b_range['b_base'])]
        for _ in range(num_points):
            b = random.choice(b_range)
            z_f, z_h = self.convert_b_to_z(d_prime, b, b)
            if not np.isfinite(z_f) or not np.isfinite(z_h):
                zf_vals.append(b/d_prime)
                zh_vals.append(b/d_prime)
            else:
                zf_vals.append(z_f)
                zh_vals.append(z_h)
            
        return zf_vals, zh_vals
    
    def sample_b_values_to_p(self, b_range, d_prime, num_points):
        
        # LR1
        pf_vals = []
        ph_vals = []
        
        if d_prime == 0:
            return zf_vals, zh_vals
        
        b_range = [n for n in np.logspace(b_range['b_min'], b_range['b_max'], b_range['b_num'], base=b_range['b_base'])]
        for _ in range(num_points):
            b = random.choice(b_range)
            p_f, p_h = self.convert_b_to_p(d_prime, b, b)
            
            pf_vals.append(p_f)
            ph_vals.append(p_h)
            
        return pf_vals, ph_vals

    def get_b_values_to_z(self, b_range, d_prime):
        
        # LR1
        zf_vals = []
        zh_vals = []
        
        if d_prime == 0:
            return zf_vals, zh_vals
        
        for b in np.logspace(b_range['b_min'], b_range['b_max'], b_range['b_num'], base=b_range['b_base']):
            if b == 0:
                continue
            z_f, z_h = self.convert_b_to_z(d_prime, b, b)
            
            zf_vals.append(z_f)
            zh_vals.append(z_h)
            
        return zf_vals, zh_vals
    
    def get_b_values_to_p(self, b_range, d_prime):
        
        # LR1
        pf_vals = []
        ph_vals = []
        
        if d_prime == 0:
            return zf_vals, zh_vals
        
        for b in np.logspace(b_range['b_min'], b_range['b_max'], b_range['b_num'], base=b_range['b_base']):
            if b == 0:
                continue
            p_f, p_h = self.convert_b_to_p(d_prime, b, b)
            
            pf_vals.append(p_f)
            ph_vals.append(p_h)
            
        return pf_vals, ph_vals
    
lr_model = LikelihoodDecisionModel()

# %% [markdown]
# # LR2 k-Value Grid Sampling

# %%
b_range = {'b_min': -10, 'b_max': 4, 'b_num': 401, 'b_base': e}
zf2_vals, zh2_vals = lr_model.sample_b1_b2_values_to_p(b_range, 2, 2000)
zf1_vals, zh1_vals = lr_model.get_b_values_to_p(b_range, 2)

plt.scatter(zf2_vals, zh2_vals, label='LR2')
plt.scatter(zf1_vals, zh1_vals, label='LR1')
plt.xlabel('p(F)')
plt.ylabel('p(H)')
plt.xlim(-0.05, 1.05)
plt.ylim(-0.05, 1.05)
plt.title('LR2 k-Sampling (d\'=2, -10<ß<4)')
plt.legend()

# %%
# LR1/LR2 k-sampling using subject slope-intercept data

b_range = {'b_min': 0, 'b_max': 4, 'b_num': 101, 'b_base': e}
dp_range = {'dp_min': 0, 'dp_max': 2, 'dp_num': 11}

mb_data = pd.read_csv('data/mb_data.csv', index_col=0)
x_vals = [-4, 4]

for dp in np.linspace(dp_range['dp_min'], dp_range['dp_max'], dp_range['dp_num']):
    zf2_vals, zh2_vals = lr_model.sample_b1_b2_values_to_z(b_range, dp, 500)
    zf1_vals, zh1_vals = lr_model.sample_b_values_to_z(b_range, dp, 500)

    plt.gcf().set_size_inches(8, 6)
    plt.scatter(zf2_vals, zh2_vals, alpha=0.3, marker='^', facecolor="none", edgecolor='black', label='LR2')
    plt.scatter(zf1_vals, zh1_vals, alpha=0.3, marker='s', facecolor="none", edgecolor='black', label='LR1')
    for index, row in mb_data.iterrows():
        slope, intercept = row['Slope'], row['Intercept']
        pred_vals = [slope * n + intercept for n in x_vals]
        plt.plot(x_vals, pred_vals, color='black', alpha=0.1)
    plt.xlabel('z(F)')
    plt.ylabel('z(H)')
    plt.xlim(-4, 4)
    plt.ylim(-4, 4)
    plt.title(f'LR k-Value Sampling (d\'={round(dp,2)}, -4<k<4)')
    plt.legend()
    plt.savefig(f'results/b_sampling{round(dp,2)}.png')
    plt.clf()
# Out:
# /Users/alexyu/.pyenv/versions/3.6.0/lib/python3.6/site-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in double_scalars
#
# /Users/alexyu/.pyenv/versions/3.6.0/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in double_scalars
#   from ipykernel import kernelapp as app
# /Users/alexyu/.pyenv/versions/3.6.0/lib/python3.6/site-packages/ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/alexyu/.pyenv/versions/3.6.0/lib/python3.6/site-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/alexyu/.pyenv/versions/3.6.0/lib/python3.6/site-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in double_scalars
#
# /Users/alexyu/.pyenv/versions/3.6.0/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in double_scalars
#   from ipykernel import kernelapp as app
# /Users/alexyu/.pyenv/versions/3.6.0/lib/python3.6/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in double_scalars
# /Users/alexyu/.pyenv/versions/3.6.0/lib/python3.6/site-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in double_scalars
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-131-4a146fcf0fa5> in <module>
#      24     plt.title(f'LR k-Value Sampling (d\'={round(dp,2)}, -4<k<4)')
#      25     plt.legend()
# ---> 26     plt.savefig(f'results/k_sampling{round(dp,2)}.png')
#      27     plt.clf()
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721     fig = gcf()
#     722     res = fig.savefig(*args, **kwargs)
# --> 723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#     725
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/matplotlib/collections.py in draw(self, renderer)
#     864     def draw(self, renderer):
#     865         self.set_sizes(self._sizes, self.figure.dpi)
# --> 866         Collection.draw(self, renderer)
#     867
#     868
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/matplotlib/collections.py in draw(self, renderer)
#     327                 self._linewidths, self._linestyles,
#     328                 self._antialiaseds, self._urls,
# --> 329                 self._offset_position)
#     330
#     331         gc.restore()
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/matplotlib/path.py in should_simplify(self)
#     249         return not np.isfinite(self._vertices).all()
#     250
# --> 251     @property
#     252     def should_simplify(self):
#     253         """
#
# KeyboardInterrupt:

# %%
# LR k-sampling w/ subject z-value data

b_range = {'b_min': 0, 'b_max': 4, 'b_num': 401, 'b_base': e}
dp_range = {'dp_min': 0.2, 'dp_max': 2.7, 'dp_num': 26}

data = pd.read_csv('data/z_data.csv', index_col=0)
x_vals = [-4, 4]
explained_subs = ['BYZ','HP','HYP','SL','YPL','YJC','ZJT','QP','TCD','YCX','ZXL','ZY','CW','WJ','RSL','SJ2','LXL','SYB','WY','YJX','CY','GJ','JYN','SJ','SXQ','ZQT']

for dp in np.linspace(dp_range['dp_min'], dp_range['dp_max'], dp_range['dp_num']):
    zf2_vals, zh2_vals = lr_model.sample_b1_b2_values_to_z(b_range, dp, 1000)
    zf1_vals, zh1_vals = lr_model.sample_b_values_to_z(b_range, dp, 500)

    plt.gcf().set_size_inches(8, 6)
    plt.scatter(zf2_vals, zh2_vals, alpha=0.3, marker='^', facecolor="none", edgecolor='black', label='LR2')
    plt.scatter(zf1_vals, zh1_vals, alpha=0.3, marker='s', facecolor="none", edgecolor='black', label='LR1')

    for i in range(len(data)):
        sub_data = data.iloc[i]
        if sub_data['Subject'] in explained_subs:
            alpha = 0.3
            zf_vals = sub_data.filter(like='ZF').tolist()
            zh_vals = sub_data.filter(like='ZH').tolist()
            plt.plot(zf_vals, zh_vals, color='black', alpha=alpha)    
    
    plt.xlabel('z(F)')
    plt.ylabel('z(H)')
    plt.xlim(-4, 4)
    plt.ylim(-4, 4)
    plt.title(f'LR k-Value Sampling (d\'={round(dp,2)}, -4<k<4)')
    plt.legend()
    plt.savefig(f'results/b_sampling{round(dp,2)}.png')
    plt.clf()

# %%
# LR k-sampling w/ subject p-value data

b_range = {'b_min': 0, 'b_max': 4, 'b_num': 401, 'b_base': e}
dp_range = {'dp_min': 0.2, 'dp_max': 2.7, 'dp_num': 26}

data = pd.read_csv('data/p_data.csv', index_col=0)
x_vals = [-4, 4]
explained_subs = ['BYZ','HP','HYP','SL','YPL','YJC','ZJT','QP','TCD','YCX','ZXL','ZY','CW','WJ','RSL','SJ2','LXL','SYB','WY','YJX','CY','GJ','JYN','SJ','SXQ','ZQT']

for dp in np.linspace(dp_range['dp_min'], dp_range['dp_max'], dp_range['dp_num']):
    pf2_vals, ph2_vals = lr_model.sample_b1_b2_values_to_p(b_range, dp, 1000)
    pf1_vals, ph1_vals = lr_model.sample_b_values_to_p(b_range, dp, 500)

    plt.gcf().set_size_inches(8, 6)
    plt.scatter(pf2_vals, ph2_vals, alpha=0.3, marker='^', facecolor="none", edgecolor='black', label='LR2')
    plt.scatter(pf1_vals, ph1_vals, alpha=0.3, marker='s', facecolor="none", edgecolor='black', label='LR1')

    for i in range(len(data)):
        sub_data = data.iloc[i]
        if sub_data['Subject'].replace('\'', "") in explained_subs:
            alpha = 0.3
            pf_vals = sub_data.filter(like='PF').tolist()
            ph_vals = sub_data.filter(like='PH').tolist()
            plt.plot(pf_vals, ph_vals, color='black', alpha=alpha)    
    
    plt.xlabel('p(F)')
    plt.ylabel('p(H)')
    plt.xlim(0, 1)
    plt.ylim(0, 1)
    plt.title(f'LR k-Value Sampling (d\'={round(dp,2)}, -4<k<4)')
    plt.legend()
    plt.savefig(f'results/b_sampling{round(dp,2)}.png')
    plt.clf()

# %%
# LR k-sampling w/ subject z-value data

b_range = {'b_min': -4, 'b_max': 4, 'b_num': 401}
dp_range = {'dp_min': 0.1, 'dp_max': 0.5, 'dp_num': 5}

data = pd.read_csv('data/z_data.csv', index_col=0)
x_vals = [-4, 4]
explained_subs = ['CSF','LT','ZBY','DLC','HMH','GAX','LMT','PC','SZJ','WYX','ZJ']

for dp in np.linspace(dp_range['dp_min'], dp_range['dp_max'], dp_range['dp_num']):
    zf1_vals, zh1_vals = lr_model.sample_b_values_to_z(b_range, dp, 500)

    plt.gcf().set_size_inches(8, 6)
    plt.scatter(zf1_vals, zh1_vals, alpha=0.3, marker='s', facecolor="none", edgecolor='black', label='LR1')

    for i in range(len(data)):
        sub_data = data.iloc[i]
        if sub_data['Subject'] in explained_subs:
            alpha = 0.3
            zf_vals = sub_data.filter(like='ZF').tolist()
            zh_vals = sub_data.filter(like='ZH').tolist()
            plt.plot(zf_vals, zh_vals, color='black', alpha=alpha)    
    
    plt.xlabel('z(F)')
    plt.ylabel('z(H)')
    plt.xlim(-4, 4)
    plt.ylim(-4, 4)
    plt.title(f'LR1 k-Value Sampling (d\'={round(dp,2)}, -4<k<4)')
    plt.legend()
    plt.savefig(f'results/b_sampling{round(dp,2)}.png')
    plt.clf()

# %%
# LR k-sampling w/ subject p-value data

b_range = {'b_min': 0, 'b_max': 4, 'b_num': 401}
dp_range = {'dp_min': 0.1, 'dp_max': 2.5, 'dp_num': 25}

alpha_value = 0.2

count = 1
is_first = True
fig = plt.figure(figsize=(36, 24))
fig.subplots_adjust(hspace=0.3, wspace=0.3)
rows, cols = 5, 5

for dp in np.linspace(dp_range['dp_min'], dp_range['dp_max'], dp_range['dp_num']):
    
    b_range = {'b_min': -10, 'b_max': dp*2.5, 'b_num': 801, 'b_base': e}
    
    pflr_vals, phlr_vals = lr_model.sample_b1_b2_values_to_p(b_range, dp, 1500)
    pfrc_vals, phrc_vals = rc_model.sample_b1_b2_values_to_p(b_range, dp, 500)
    
    ax = fig.add_subplot(rows, cols, count)
    ax.scatter(pfrc_vals, phrc_vals, alpha=0.3, marker='^', color='r', label='RC2a', zorder=1)
    if dp >= 1:
        points = np.column_stack((pfrc_vals, phrc_vals))
        edges = alpha_shape(points, alpha=alpha_value, only_outer=True)
        for i, j in edges:
            ax.plot(points[[i, j], 0], points[[i, j], 1], color='r', zorder=2)
    
    ax.scatter(pflr_vals, phlr_vals, alpha=0.3, marker='.', color='black', label='LR2')
    if dp >= 1:
        points = np.column_stack((pflr_vals, phlr_vals))
        edges = alpha_shape(points, alpha=alpha_value, only_outer=True)
        for i, j in edges:
            ax.plot(points[[i, j], 0], points[[i, j], 1], color='black', zorder=2)
    
    ax.set_xlim(-0.05, 1.05)
    ax.set_ylim(-0.05, 1.05)
    ax.text(0.5, 0.05, "Model $\it{d\'}$=" + f"{round(dp, 3)}", transform=ax.transAxes, ha='center', fontsize=8)
    
    if is_first:
        ax.text(0.05, 0.9, 'Comparison Between RC2a and LR2', transform=ax.transAxes, ha='left')
        ax.set_xlabel('p(F)')
        ax.set_ylabel('p(H)')
        ax.legend(loc=4)
        is_first=False
    else:
        ax.axes.get_xaxis().set_visible(False)
        ax.axes.get_yaxis().set_visible(False)
    
    fig.savefig(f'results/RC2a_LR2_Comparison.pdf')
    count += 1
# Out:
# /Users/alexyu/.pyenv/versions/3.6.0/lib/python3.6/site-packages/ipykernel_launcher.py:50: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/alexyu/.pyenv/versions/3.6.0/lib/python3.6/site-packages/ipykernel_launcher.py:50: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/alexyu/.pyenv/versions/3.6.0/lib/python3.6/site-packages/ipykernel_launcher.py:50: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/alexyu/.pyenv/versions/3.6.0/lib/python3.6/site-packages/ipykernel_launcher.py:50: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/alexyu/.pyenv/versions/3.6.0/lib/python3.6/site-packages/ipykernel_launcher.py:50: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/alexyu/.pyenv/versions/3.6.0/lib/python3.6/site-packages/ipykernel_launcher.py:49: RuntimeWarning: invalid value encountered in sqrt

# %% [markdown]
# # LR2 Boundary Characterization

# %%
from shapely import geometry
from scipy.spatial import Delaunay
import numpy as np

def alpha_shape(points, alpha, only_outer=True):
    """
    Compute the alpha shape (concave hull) of a set of points.
    :param points: np.array of shape (n,2) points.
    :param alpha: alpha value.
    :param only_outer: boolean value to specify if we keep only the outer border
    or also inner edges.
    :return: set of (i,j) pairs representing edges of the alpha-shape. (i,j) are
    the indices in the points array.
    """
    assert points.shape[0] > 3, "Need at least four points"

    def add_edge(edges, i, j):
        """
        Add an edge between the i-th and j-th points,
        if not in the list already
        """
        if (i, j) in edges or (j, i) in edges:
            # already added
            assert (j, i) in edges, "Can't go twice over same directed edge right?"
            if only_outer:
                # if both neighboring triangles are in shape, it's not a boundary edge
                edges.remove((j, i))
            return
        edges.add((i, j))

    try:
        tri = Delaunay(points)
    except:
        print('Shape too flat!')
        return set()
    edges = set()
    # Loop over triangles:
    # ia, ib, ic = indices of corner points of the triangle
    for ia, ib, ic in tri.vertices:
        pa = points[ia]
        pb = points[ib]
        pc = points[ic]
        # Computing radius of triangle circumcircle
        # www.mathalino.com/reviewer/derivation-of-formulas/derivation-of-formula-for-radius-of-circumcircle
        a = np.sqrt((pa[0] - pb[0]) ** 2 + (pa[1] - pb[1]) ** 2)
        b = np.sqrt((pb[0] - pc[0]) ** 2 + (pb[1] - pc[1]) ** 2)
        c = np.sqrt((pc[0] - pa[0]) ** 2 + (pc[1] - pa[1]) ** 2)
        s = (a + b + c) / 2.0
        area = np.sqrt(s * (s - a) * (s - b) * (s - c))
        circum_r = a * b * c / (4.0 * area)
        if circum_r < alpha:
            add_edge(edges, ia, ib)
            add_edge(edges, ib, ic)
            add_edge(edges, ic, ia)
    return edges

def find_edges_with(i, edge_set):
    i_first = [j for (x,j) in edge_set if x==i]
    i_second = [j for (j,x) in edge_set if x==i]
    return i_first,i_second

def stitch_boundaries(edges):
    edge_set = edges.copy()
    boundary_lst = []
    while len(edge_set) > 0:
        boundary = []
        edge0 = edge_set.pop()
        boundary.append(edge0)
        last_edge = edge0
        while len(edge_set) > 0:
            i,j = last_edge
            j_first, j_second = find_edges_with(j, edge_set)
            if j_first:
                edge_set.remove((j, j_first[0]))
                edge_with_j = (j, j_first[0])
                boundary.append(edge_with_j)
                last_edge = edge_with_j
            elif j_second:
                edge_set.remove((j_second[0], j))
                edge_with_j = (j, j_second[0])  # flip edge rep
                boundary.append(edge_with_j)
                last_edge = edge_with_j

            if edge0[0] == last_edge[1]:
                break

        boundary_lst.append(boundary)
    return boundary_lst

# %%
dp_range = {'dp_min': 0, 'dp_max': 2.5, 'dp_num': 101}
num_of_pts = 2000

lr1_model_data = dict()

for dp in np.linspace(dp_range['dp_min'], dp_range['dp_max'], dp_range['dp_num']):
    if dp == 0:
        continue
    
    b_range = {'b_min': -10, 'b_max': dp*2.5, 'b_num': 801, 'b_base': e}
    zfm_vals, zhm_vals = lr_model.get_b_values_to_z(b_range, dp)
    zfm_vals_new = [zfm_vals[i] for i in range(len(zfm_vals)) if np.isfinite(zfm_vals)[i] and np.isfinite(zhm_vals)[i]]
    zhm_vals_new = [zhm_vals[i] for i in range(len(zhm_vals)) if np.isfinite(zfm_vals)[i] and np.isfinite(zhm_vals)[i]]
    zfm_vals, zhm_vals = zfm_vals_new, zhm_vals_new
                      
    lr1_model_data[dp] = [zfm_vals, zhm_vals]
    
lr1_p_model_data = {key: [[st.norm.cdf(z) for z in lr1_model_data[key][0]], [st.norm.cdf(z) for z in lr1_model_data[key][1]]] for key in lr1_model_data}

# %%
dp_range = {'dp_min': 0, 'dp_max': 2.5, 'dp_num': 101}
num_of_pts = 2000

lr2_model_data = dict()

for dp in np.linspace(dp_range['dp_min'], dp_range['dp_max'], dp_range['dp_num']):
    if dp == 0:
        continue
    
    b_range = {'b_min': -10, 'b_max': dp*2.5, 'b_num': 801, 'b_base': e}
    
    zfm_vals, zhm_vals = lr_model.sample_b1_b2_values_to_z(b_range, dp, num_of_pts)
    zfm_vals_new = [zfm_vals[i] for i in range(len(zfm_vals)) if np.isfinite(zfm_vals)[i] and np.isfinite(zhm_vals)[i]]
    zhm_vals_new = [zhm_vals[i] for i in range(len(zhm_vals)) if np.isfinite(zfm_vals)[i] and np.isfinite(zhm_vals)[i]]
    zfm_vals, zhm_vals = zfm_vals_new, zhm_vals_new
                      
    lr2_model_data[dp] = [zfm_vals, zhm_vals]
    
lr2_p_model_data = {key: [[st.norm.cdf(z) for z in lr2_model_data[key][0]], [st.norm.cdf(z) for z in lr2_model_data[key][1]]] for key in lr2_model_data}

# %%
# %%capture --no-stdout

z_data = pd.read_csv('data/z_data.csv', index_col=1)
explained_subs = ['CW','CY','GJ','JYN','LXL','RSL','SJ2','SJ','SXQ','SYB','WJ','WY','YJX','ZQT','BYZ','HP','HYP','QP','SL','TCD','YCX','YJC','YPL','ZJT','ZXL','ZY']
explained_subs.sort()

alpha_value = 0.25

count = 1
is_first = True
fig = plt.figure(figsize=(42, 24))
fig.subplots_adjust(hspace=0.3, wspace=0.3)
rows, cols = 5, 6

df = pd.DataFrame(columns=['Subject', 'LR2 d\'', 'LR2 Contained Pts'])

for subject in explained_subs:
    z_sub_data = z_data.loc[subject]
    zf_vals = [n for n in z_sub_data.filter(like='ZF').tolist() if n != 0]
    zh_vals = [n for n in z_sub_data.filter(like='ZH').tolist() if n != 0]
    pf_vals = [st.norm.cdf(z) for z in zf_vals]
    ph_vals = [st.norm.cdf(z) for z in zh_vals]
    
    '''
    Optimal LR2 w/ Corresponding LR1 and Human Data
    '''
    
    best_dp, points_explained, total_out_dist = 0, 0, np.inf
    for dp in lr2_p_model_data.keys():
        
        if float(dp) == 0:
            continue
        
        pfm_vals, phm_vals = lr2_p_model_data[dp]
        
        # Find boundaries of cloud and calculate number of points within cloud
        points = np.column_stack((pfm_vals, phm_vals))
        edges = alpha_shape(points, alpha=alpha_value, only_outer=True)
        boundaries = stitch_boundaries(edges)[0]
        edge_pts = [points[pt[0]] for pt in boundaries]
        cloud = geometry.Polygon(edge_pts)
        
        num_explained = [cloud.contains(geometry.Point(pf, ph)) for pf, ph in zip(pf_vals, ph_vals)].count(True)
        
        if num_explained > points_explained:
            best_dp = dp
            points_explained = num_explained
            total_out_dist = 0
            
            # Calculate new baseline for outlier distance
            for pf, ph in zip(pf_vals, ph_vals):
                point = geometry.Point(pf, ph)
                if not cloud.contains(point):
                    total_out_dist += cloud.exterior.distance(point)
        elif num_explained == points_explained:
            curr_out_dist = 0
            
            # Check if current outlier distance is less than best
            for pf, ph in zip(pf_vals, ph_vals):
                point = geometry.Point(pf, ph)
                if not cloud.contains(point):
                    curr_out_dist += cloud.exterior.distance(point)
            if curr_out_dist < total_out_dist:
                best_dp = dp
                total_out_dist = curr_out_dist
    
    print(f"{subject}: {points_explained} points explained with d\'={round(float(best_dp), 3)} w/ optimal LR2")
    df.loc[len(df)] = [subject, round(float(best_dp), 3), points_explained]

    subject_acc = f"{'{:.2f}'.format(round(z_sub_data['Accuracy'], 3))}"
    model_acc = f"{'{:.3f}'.format(round((st.norm.cdf(float(best_dp)/2))**2 + (st.norm.cdf(-float(best_dp)/2))**2, 3))}"
    ax = fig.add_subplot(rows, cols, count)
    
    # Plot LR2 model cloud boundary
    pfm_vals, phm_vals = lr2_p_model_data[best_dp]
    points = np.column_stack((pfm_vals, phm_vals))
    edges = alpha_shape(points, alpha=alpha_value, only_outer=True)
    for i, j in edges:
        ax.plot(points[[i, j], 0], points[[i, j], 1], alpha=0.3, color='black', zorder=1)
        
    # Plot LR2 model cloud
    ax.scatter(pfm_vals, phm_vals, alpha=0.1, label='LR2', color='black', marker='.')
    
    # Plot LR1 ROC
    pfm_vals, phm_vals = lr1_p_model_data[best_dp]
    ax.plot(pfm_vals, phm_vals, label='LR1', color='black')
    
    # Plot human data points
    ax.scatter(pf_vals, ph_vals, label='Human', color='black', marker='s')
    
    # Format plots accordingly
    dp_str = f"{'{:.3f}'.format(round(float(best_dp), 3))}"
    ax.text(0.5, 0.05, f"Subject {subject}\n" + "Model $\it{d\'}$=" + f"{dp_str}", transform=ax.transAxes, ha='center', fontsize=8)
    ax.text(0.63, 0.3, "$\it{P}$$_c$: " + f"{subject_acc} (human),\n     {model_acc} (optimal model)", transform=ax.transAxes, ha='left', fontsize=8)
    
    if is_first:
        ax.text(0.03, 0.87, 'Best-fit LR2, Corresponding LR1, \nand Human Data', transform=ax.transAxes, ha='left')
        ax.set_xlabel('p(F)')
        ax.set_ylabel('p(H)')
        ax.legend(loc=4, prop={'size': 8})
        is_first = False
    else:
        ax.axes.get_xaxis().set_visible(False)
        ax.axes.get_yaxis().set_visible(False)
        
    #extent = ax.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
    #fig.savefig(f'results/output/LR2_boundary_{subject}.svg', bbox_inches=extent)
    count += 1
    
    fig.savefig('results/LR2_boundary.pdf')
    fig.savefig('results/LR2_boundary.svg')
# Out:
# BYZ: 2 points explained with d'=0.525 w/ optimal LR2
# CW: 4 points explained with d'=2.075 w/ optimal LR2
# CY: 2 points explained with d'=2.2 w/ optimal LR2
# GJ: 3 points explained with d'=2.325 w/ optimal LR2
# HP: 1 points explained with d'=0.525 w/ optimal LR2
# HYP: 2 points explained with d'=1.5 w/ optimal LR2
# JYN: 3 points explained with d'=1.15 w/ optimal LR2
# LXL: 4 points explained with d'=2.225 w/ optimal LR2
# QP: 3 points explained with d'=1.375 w/ optimal LR2
# RSL: 1 points explained with d'=2.5 w/ optimal LR2
# SJ: 3 points explained with d'=2.025 w/ optimal LR2
# SJ2: 2 points explained with d'=0.9 w/ optimal LR2
# SL: 3 points explained with d'=1.225 w/ optimal LR2
# SXQ: 3 points explained with d'=2.025 w/ optimal LR2
# SYB: 2 points explained with d'=2.5 w/ optimal LR2
# TCD: 4 points explained with d'=0.9 w/ optimal LR2
# WJ: 2 points explained with d'=2.225 w/ optimal LR2
# WY: 1 points explained with d'=2.5 w/ optimal LR2
# YCX: 2 points explained with d'=0.625 w/ optimal LR2
# YJC: 3 points explained with d'=0.7 w/ optimal LR2
# YJX: 4 points explained with d'=2.5 w/ optimal LR2
# YPL: 3 points explained with d'=1.925 w/ optimal LR2
# ZJT: 2 points explained with d'=0.85 w/ optimal LR2
# ZQT: 2 points explained with d'=1.025 w/ optimal LR2
# ZXL: 2 points explained with d'=1.375 w/ optimal LR2
# ZY: 4 points explained with d'=0.95 w/ optimal LR2

# %% [markdown]
# # Analyzing LR1 ROC Fit

# %%
def distance(point, coef):
    return abs((coef[0]*point[0])-point[1]+coef[1])/math.sqrt((coef[0]*coef[0])+1)

def p4(p1, p2, p3):
    x1, y1 = p1
    x2, y2 = p2
    x3, y3 = p3
    dx, dy = x2-x1, y2-y1
    det = dx*dx + dy*dy
    a = (dy*(y3-y1)+dx*(x3-x1))/det
    return x1+a*dx, y1+a*dy

def f(B, x):
    return B[0]*x + B[1]
linear = odrpack.Model(f)

# %%
b_range = {'b_min': -8, 'b_max': 4, 'b_num': 801, 'b_base': e}
dp_range = {'dp_min': 0, 'dp_max': 2.5, 'dp_num': 101}

z_data = pd.read_csv('data/z_data.csv', index_col=0)
x_vals = [-5, 5]
explained_subs = ['CSF','LT','ZBY','DLC','HMH','GAX','LMT','PC','SZJ','WYX','ZJ']

count = 1
is_first = True
rows, cols = 3, 4

fig_z = plt.figure(figsize=(27, 15))
fig_z.subplots_adjust(hspace=0.5, wspace=0.3)
fig_p = plt.figure(figsize=(27, 15))
fig_p.subplots_adjust(hspace=0.5, wspace=0.3)

for i in range(len(z_data)):
    
    z_sub_data = z_data.iloc[i]
    subject = z_sub_data['Subject'].replace('\'', "")

    if subject in explained_subs:    

        # Unpack subject data
        zf_vals = [n for n in z_sub_data.filter(like='ZF').tolist() if n != 0]
        zh_vals = [n for n in z_sub_data.filter(like='ZH').tolist() if n != 0]
        pf_vals = [st.norm.cdf(z) for z in zf_vals]
        ph_vals = [st.norm.cdf(z) for z in zh_vals]

        # Find subject TLS regression line
        odr_data = odrpack.RealData(zf_vals, zh_vals)
        odr = odrpack.ODR(odr_data, linear, beta0=[1., 1.])
        subject_slope, subject_intercept = odr.run().beta
        print(f'{subject} TLS slope: {subject_slope}')
        
        coef = [subject_slope, subject_intercept]
        
        # Find d' that yields closest fitting z-ROC
        lowest_tls = np.inf
        best_dp = 0
        for dp in np.linspace(dp_range['dp_min'], dp_range['dp_max'], dp_range['dp_num']):
            if dp == 0:
                continue
            
            b_range['b_max'] = 2.5*dp
            zfm_vals, zhm_vals = lr_model.get_b_values_to_z(b_range, dp)
            zfm_vals_new = [zfm_vals[i] for i in range(len(zfm_vals)) if zfm_vals[i] <= 1.2*max(zf_vals) and zhm_vals[i] <= 1.2*max(zh_vals) and zfm_vals[i] >= 1.2*min(zf_vals) and zhm_vals[i] >= 1.2*min(zh_vals)]
            zhm_vals_new = [zhm_vals[i] for i in range(len(zhm_vals)) if zfm_vals[i] <= 1.2*max(zf_vals) and zhm_vals[i] <= 1.2*max(zh_vals) and zfm_vals[i] >= 1.2*min(zf_vals) and zhm_vals[i] >= 1.2*min(zh_vals)]
            zfm_vals, zhm_vals = zfm_vals_new, zhm_vals_new
            
            if len(zfm_vals) < 2:
                continue
            
            tls = np.mean([distance([f, h], coef) for f, h in zip(zfm_vals, zhm_vals)])

            if tls < lowest_tls:
                lowest_tls = tls
                best_dp = dp

        # Calculate R^2
        p1 = (-5, subject_intercept + subject_slope * -5)
        p2 = (5, subject_intercept + subject_slope * 5)
        zfm_vals, zhm_vals = lr_model.get_b_values_to_z(b_range, best_dp)
        zfm_vals_new = [zfm_vals[i] for i in range(len(zfm_vals)) if zfm_vals[i] <= 1.2*max(zf_vals) and zhm_vals[i] <= 1.2*max(zh_vals) and zfm_vals[i] >= 1.2*min(zf_vals) and zhm_vals[i] >= 1.2*min(zh_vals)]
        zhm_vals_new = [zhm_vals[i] for i in range(len(zhm_vals)) if zfm_vals[i] <= 1.2*max(zf_vals) and zhm_vals[i] <= 1.2*max(zh_vals) and zfm_vals[i] >= 1.2*min(zf_vals) and zhm_vals[i] >= 1.2*min(zh_vals)]
        zfm_vals, zhm_vals = zfm_vals_new, zhm_vals_new
        ssr = np.sum([(mx - p4(p1, p2, (mx, my))[0])**2 + (my - p4(p1, p2, (mx, my))[1])**2 for mx, my in zip(zfm_vals, zhm_vals)])
        sst = np.sum([(mx - np.mean(zfm_vals))**2 + (my - np.mean(zhm_vals))**2 for mx, my in zip(zfm_vals, zhm_vals)])
        r_squared = round(1 - ssr/sst, 3)
        
        print(f"TLS value: {lowest_tls}\tR^2: {r_squared}")
        
        ax = fig_z.add_subplot(rows, cols, count)
        
        # Plot z-ROC
        y_pred = [subject_intercept + subject_slope * n for n in x_vals]
        ax.scatter(zf_vals, zh_vals, color='black', label='Human Data', marker='s')
        zfm_vals, zhm_vals = lr_model.get_b_values_to_z(b_range, best_dp)
        ax.plot(x_vals, y_pred, color='black', linestyle='--', alpha=0.2, label=f'Human ROC')
        ax.plot(zfm_vals, zhm_vals, color='black', alpha=0.5, label='Model ROC')
        #ax.scatter(zfm_vals, zhm_vals, alpha=0.2, color='black')

        ax.set_xlim(-4, 4)
        ax.set_ylim(-4, 4)
        subject_acc = round(z_sub_data['Accuracy'], 3)
        model_acc = round((st.norm.cdf(best_dp/2))**2 + (st.norm.cdf(-best_dp/2))**2, 3)
        ax.text(0.5, 0.05, f"Subject {subject}\n" + "Model $\it{d\'}$=" + f"{round(best_dp, 3)}", transform=ax.transAxes, ha='center', fontsize=8)
        ax.text(0.63, 0.3, "$\it{P}$$_c$: " + f"{subject_acc} (human),\n     {model_acc} (optimal model)", transform=ax.transAxes, ha='left', fontsize=8)
        
        if is_first:
            ax.set_xlabel('z(F)')
            ax.set_ylabel('z(H)')
            ax.set_title(f'LR1 ROC Fitting Using TLS')
            ax.legend(loc=4, prop={'size': 8})
        else:
            ax.axes.get_xaxis().set_visible(False)
            ax.axes.get_yaxis().set_visible(False)
            
        fig_z.savefig('results/LR1_z.pdf')
        
        # Plot p-ROC
        ax = fig_p.add_subplot(rows, cols, count)
        ax.scatter(pf_vals, ph_vals, color='black', label='Human Data', marker='s')
        temp_x = np.linspace(-4, 4, 26)
        y_pred = [subject_intercept + subject_slope * n for n in temp_x]
        temp_x = [st.norm.cdf(val) for val in temp_x]
        y_pred = [st.norm.cdf(val) for val in y_pred]
        ax.plot(temp_x, y_pred, color='black', linestyle='--', alpha=0.2, label='Human ROC')
        pfm_vals, phm_vals = lr_model.get_b_values_to_p(b_range, best_dp)
        ax.plot(pfm_vals, phm_vals, color='black', alpha=0.5, label='Model ROC')
        ax.text(0.5, 0.05, f"Subject {subject}\n" + "Model $\it{d\'}$=" + f"{round(best_dp, 3)}", transform=ax.transAxes, ha='center', fontsize=8)
        ax.text(0.63, 0.3, "$\it{P}$$_c$: " + f"{subject_acc} (human),\n     {model_acc} (optimal model)", transform=ax.transAxes, ha='left', fontsize=8)
        
        if is_first:
            ax.set_xlabel('p(F)')
            ax.set_ylabel('p(H)')
            ax.set_title(f'LR1 Subject ROC Fitting Using TLS')
            ax.legend(loc=4, prop={'size': 8})
            is_first=False
        else:
            ax.axes.get_xaxis().set_visible(False)
            ax.axes.get_yaxis().set_visible(False)
            
        ax.set_xlim((-0.05580765917234185, 1.0557949748623252))
        ax.set_ylim((-0.05580765917234185, 1.0557949748623252))
    
        fig_p.savefig('results/LR1_p.pdf')

        count += 1
# Out:
# CSF TLS slope: 1.0028619619006445
# TLS value: 0.032446959551764444	R^2: 1.0
# LT TLS slope: 0.905964790070835
# TLS value: 0.047123792245386154	R^2: 0.998
# ZBY TLS slope: 0.8016524510555929
# TLS value: 0.08026505656866699	R^2: 0.989
# DLC TLS slope: 1.0277976800645598
# TLS value: 0.012835394680592645	R^2: 1.0
# GAX TLS slope: 1.1368243854933529
# TLS value: 0.14624140437507363	R^2: 0.994
# HMH TLS slope: 1.0062878358531209
# TLS value: 0.009697419573890566	R^2: 1.0
# LMT TLS slope: 1.045244291738568
# TLS value: 0.06337250409864399	R^2: 0.999
# PC TLS slope: 0.9450103493481479
# TLS value: 0.03009619326510857	R^2: 0.999
# SZJ TLS slope: 1.010588634237981
# TLS value: 0.011134058310663818	R^2: 1.0
# WYX TLS slope: 1.16648171357917
# TLS value: 0.11838420041541153	R^2: 0.99
# ZJ TLS slope: 1.0048930538391838
# TLS value: 0.005819068004676779	R^2: 1.0
